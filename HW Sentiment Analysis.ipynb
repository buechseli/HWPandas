# %%
# Dependencies
import numpy as np
import pandas as pd
import tweepy
import time
import json
from datetime import datetime
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# Twitter API Keys
consumer_key = consumer_key
consumer_secret = consumer_secret
access_token = access_token
access_token_secret = access_token_secret

# %%
# Twitter Credentials
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Extract all hashtags from tweets directed to the account
my_username = "@Isa_EscRiv"

# %%
# Search for most recent 500 tweets directed to the account
public_tweets = api.search(my_username, count=500, result_type="recent")

# %%
# Search for most recent tweet directed to the account

for my_tweet in public_tweets["statuses"]:

    # Print tweet in JSON
    print(json.dumps(my_tweet, sort_keys=True, indent=4, separators=(',', ': ')))
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Apr 05 16:50:21 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 979172239403708416,
#                 "id_str": "979172239403708416",
#                 "indices": [
#                     11,
#                     22
#                 ],
#                 "name": "Isabel Escobar",
#                 "screen_name": "Isa_EscRiv"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 981937092992225283,
#     "id_str": "981937092992225283",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#     },
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"https://www.searchtweets123.com\" rel=\"nofollow\">Search_Tweets_Bootcamp</a>",
#     "text": "Thank You! @Isa_EscRiv",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu Mar 29 01:35:00 +0000 2018",
#         "default_profile": true,
#         "default_profile_image": true,
#         "description": "",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 0,
#         "follow_request_sent": false,
#         "followers_count": 2,
#         "following": true,
#         "friends_count": 7,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 979170021992677376,
#         "id_str": "979170021992677376",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 0,
#         "location": "",
#         "name": "Grace",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#         "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "929_grace",
#         "statuses_count": 16,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Apr 05 04:51:21 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 979172239403708416,
#                 "id_str": "979172239403708416",
#                 "indices": [
#                     4,
#                     15
#                 ],
#                 "name": "Isabel Escobar",
#                 "screen_name": "Isa_EscRiv"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 981756150742827008,
#     "id_str": "981756150742827008",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#     },
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"https://web.com\" rel=\"nofollow\">SearchYourTweets</a>",
#     "text": "Hey @Isa_EscRiv! YOU ARE COOL!",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu Mar 29 01:43:48 +0000 2018",
#         "default_profile": true,
#         "default_profile_image": true,
#         "description": "",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 0,
#         "follow_request_sent": false,
#         "followers_count": 1,
#         "following": false,
#         "friends_count": 3,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 979172239403708416,
#         "id_str": "979172239403708416",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 0,
#         "location": "",
#         "name": "Isabel Escobar",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#         "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "Isa_EscRiv",
#         "statuses_count": 16,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Apr 05 04:50:43 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 979172239403708416,
#                 "id_str": "979172239403708416",
#                 "indices": [
#                     3,
#                     14
#                 ],
#                 "name": "Isabel Escobar",
#                 "screen_name": "Isa_EscRiv"
#             },
#             {
#                 "id": 979170021992677376,
#                 "id_str": "979170021992677376",
#                 "indices": [
#                     16,
#                     26
#                 ],
#                 "name": "Grace",
#                 "screen_name": "929_grace"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 981755993561313281,
#     "id_str": "981755993561313281",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#     },
#     "place": null,
#     "retweet_count": 1,
#     "retweeted": false,
#     "retweeted_status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Thu Apr 05 04:39:20 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [],
#             "user_mentions": [
#                 {
#                     "id": 979170021992677376,
#                     "id_str": "979170021992677376",
#                     "indices": [
#                         0,
#                         10
#                     ],
#                     "name": "Grace",
#                     "screen_name": "929_grace"
#                 }
#             ]
#         },
#         "favorite_count": 0,
#         "favorited": false,
#         "geo": null,
#         "id": 981753128402866176,
#         "id_str": "981753128402866176",
#         "in_reply_to_screen_name": "929_grace",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": 979170021992677376,
#         "in_reply_to_user_id_str": "979170021992677376",
#         "is_quote_status": false,
#         "lang": "en",
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "place": null,
#         "retweet_count": 1,
#         "retweeted": false,
#         "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#         "text": "@929_grace call the function :)",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Thu Mar 29 01:43:48 +0000 2018",
#             "default_profile": true,
#             "default_profile_image": true,
#             "description": "",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "favourites_count": 0,
#             "follow_request_sent": false,
#             "followers_count": 1,
#             "following": false,
#             "friends_count": 3,
#             "geo_enabled": false,
#             "has_extended_profile": false,
#             "id": 979172239403708416,
#             "id_str": "979172239403708416",
#             "is_translation_enabled": false,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 0,
#             "location": "",
#             "name": "Isabel Escobar",
#             "notifications": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#             "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "Isa_EscRiv",
#             "statuses_count": 16,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": null,
#             "utc_offset": null,
#             "verified": false
#         }
#     },
#     "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#     "text": "RT @Isa_EscRiv: @929_grace call the function :)",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu Mar 29 01:43:48 +0000 2018",
#         "default_profile": true,
#         "default_profile_image": true,
#         "description": "",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 0,
#         "follow_request_sent": false,
#         "followers_count": 1,
#         "following": false,
#         "friends_count": 3,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 979172239403708416,
#         "id_str": "979172239403708416",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 0,
#         "location": "",
#         "name": "Isabel Escobar",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#         "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "Isa_EscRiv",
#         "statuses_count": 16,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Apr 05 04:50:14 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 979172239403708416,
#                 "id_str": "979172239403708416",
#                 "indices": [
#                     11,
#                     22
#                 ],
#                 "name": "Isabel Escobar",
#                 "screen_name": "Isa_EscRiv"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 981755872283013120,
#     "id_str": "981755872283013120",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#     },
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"https://www.searchtweets123.com\" rel=\"nofollow\">Search_Tweets_Bootcamp</a>",
#     "text": "Thank You! @Isa_EscRiv",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu Mar 29 01:35:00 +0000 2018",
#         "default_profile": true,
#         "default_profile_image": true,
#         "description": "",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 0,
#         "follow_request_sent": false,
#         "followers_count": 2,
#         "following": true,
#         "friends_count": 7,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 979170021992677376,
#         "id_str": "979170021992677376",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 0,
#         "location": "",
#         "name": "Grace",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#         "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "929_grace",
#         "statuses_count": 16,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Apr 05 04:04:28 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 979172239403708416,
#                 "id_str": "979172239403708416",
#                 "indices": [
#                     0,
#                     11
#                 ],
#                 "name": "Isabel Escobar",
#                 "screen_name": "Isa_EscRiv"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 981744354887794688,
#     "id_str": "981744354887794688",
#     "in_reply_to_screen_name": "Isa_EscRiv",
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": 979172239403708416,
#     "in_reply_to_user_id_str": "979172239403708416",
#     "is_quote_status": false,
#     "lang": "en",
#     "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#     },
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#     "text": "@Isa_EscRiv Hello!",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu Mar 29 01:35:00 +0000 2018",
#         "default_profile": true,
#         "default_profile_image": true,
#         "description": "",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 0,
#         "follow_request_sent": false,
#         "followers_count": 2,
#         "following": true,
#         "friends_count": 7,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 979170021992677376,
#         "id_str": "979170021992677376",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 0,
#         "location": "",
#         "name": "Grace",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#         "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "929_grace",
#         "statuses_count": 16,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }

# %%
print('@' + screen_name)
# Out:
# @929_grace

# %%
screen = '@' + screen_name

# %%
#Sentiment Analysis
# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Target Account
target_user = screen

# Counter
counter = 1

# Variables for holding sentiments
sentiments = []

# Variable for max_id
oldest_tweet = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user, max_id = oldest_tweet)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        tweets_ago = counter
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        
        # Add to counter 
        counter += 1

# %%
# Convert sentiments to DataFrame
sentiments_pd = pd.DataFrame.from_dict(sentiments)
sentiments_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.4199  Thu Apr 05 16:50:21 +0000 2018     0.417      0.0     0.583
# 1    0.4199  Thu Apr 05 16:50:21 +0000 2018     0.417      0.0     0.583
# 2    0.4199  Thu Apr 05 04:50:14 +0000 2018     0.417      0.0     0.583
# 3    0.4199  Thu Apr 05 04:50:14 +0000 2018     0.417      0.0     0.583
# 4    0.4199  Thu Apr 05 04:38:46 +0000 2018     0.264      0.0     0.736
#
#    Tweets Ago
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5

# %%
# Create plot
x_vals = sentiments_pd["Tweets Ago"]
y_vals = sentiments_pd["Compound"]
plt.plot(x_vals,
         y_vals, marker="o", linewidth=0.5,
         alpha=0.8)

# # Incorporate the other graph properties
now = datetime.now()
now = now.strftime("%Y-%m-%d %H:%M")
plt.title(f"Sentiment Analysis of Tweets ({now}) for {target_user}")
plt.xlim([x_vals.max(),x_vals.min()]) #Bonus
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.show()
